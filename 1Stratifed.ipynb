# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import  seaborn as sns
from scipy.stats import uniform as sp_randFloat
from scipy.stats import randint as sp_randInt 
# %matplotlib


# Importing the dataset
train1 = pd.read_csv('dataset/hackathon.csv/Train.csv')
# Importing the dataset
test = pd.read_csv('dataset/hackathon.csv/Test.csv')
# dataset.describe()
# dataset.info()
# Out:
# /home/paul/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train = train1.drop(columns=['default_status'])

# %%
allfeat =  pd.concat([train,test],axis=0)

# %%
allfeat
# Out:
#         Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0      Apcnt_1000000       3436.0      0.28505       1.6560       0.0000
# 1      Apcnt_1000004       3456.0      0.67400       0.2342       0.0000
# 2      Apcnt_1000008       3276.0      0.53845       3.1510       0.0000
# 3      Apcnt_1000012       3372.0      0.17005       0.5050       0.0000
# 4      Apcnt_1000016       3370.0      0.77270       1.1010       0.0000
# ...              ...          ...          ...          ...          ...
# 23995   Apcnt_999940       3258.0      0.37925       0.5698       5.1282
# 23996   Apcnt_999956       3514.0      0.95260       0.0000       0.0000
# 23997   Apcnt_999976       3302.0      0.05755       4.2394       0.0000
# 23998   Apcnt_999984       3334.0      0.75670       1.4428       0.0000
# 23999   Apcnt_999992       3324.0      0.44840       2.3170       6.7176
#
#        form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# ...

# %%
# print(train.info())
# # print(train.shape)
# print(test.shape)

# %%
allfeat=allfeat.drop(columns=['Applicant_ID'])

# %%
allfeat = pd.concat([allfeat,pd.get_dummies(allfeat['form_field47'])],axis=1)

# %%
allfeat=allfeat.drop(columns=['form_field47'])

# %%
allfeat.head(4)
# Out:
#    form_field1  form_field2  form_field3  form_field4  form_field5  \
# 0       3436.0      0.28505       1.6560          0.0        0.000
# 1       3456.0      0.67400       0.2342          0.0        0.000
# 2       3276.0      0.53845       3.1510          0.0        6.282
# 3       3372.0      0.17005       0.5050          0.0        0.000
#
#    form_field6  form_field7  form_field8  form_field9  form_field10  ...  \
# 0          0.0   10689720.0     252072.0    4272776.0    11333126.0  ...
# 1          0.0     898979.0     497531.0    9073814.0     2533168.0  ...
# 2          NaN     956940.0          NaN     192944.0     1079864.0  ...
# 3     192166.0    3044703.0     385499.0    3986472.0     3621979.0  ...
#
#    form_field42  form_field43  form_field44  form_field45  form_field46  \
# 0      0.392854          2.02      0.711632           0.0           0.0
# 1      0.314281          8.08      0.183584           NaN           0.0
# ...

# %%
allfeat.fillna(-999,inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()

# %%
allfeat = pd.DataFrame(scalar.fit_transform(allfeat),
                      columns=allfeat.columns)

# %%
print(list(allfeat))
# Out:
# ['form_field1', 'form_field2', 'form_field3', 'form_field4', 'form_field5', 'form_field6', 'form_field7', 'form_field8', 'form_field9', 'form_field10', 'form_field11', 'form_field12', 'form_field13', 'form_field14', 'form_field15', 'form_field16', 'form_field17', 'form_field18', 'form_field19', 'form_field20', 'form_field21', 'form_field22', 'form_field23', 'form_field24', 'form_field25', 'form_field26', 'form_field27', 'form_field28', 'form_field29', 'form_field30', 'form_field31', 'form_field32', 'form_field33', 'form_field34', 'form_field35', 'form_field36', 'form_field37', 'form_field38', 'form_field39', 'form_field40', 'form_field41', 'form_field42', 'form_field43', 'form_field44', 'form_field45', 'form_field46', 'form_field48', 'form_field49', 'form_field50', 'charge', 'lending']

# %%
allfeat.shape
# Out:
# (80000, 51)

# %%
X = allfeat[:][0:56000]

# %%
testdf=allfeat[:][56000:80000]

# %%
train1=pd.concat([train1,pd.get_dummies(train1['default_status'],drop_first=True)],axis=1)
#one-hot encoding the Title categories
train1=train1.drop(columns='default_status')
#column no longer needed

# %%
y=train1['yes']
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 55995    0
# 55996    1
# 55997    0
# 55998    0
# 55999    0
# Name: yes, Length: 56000, dtype: uint8

# %%
allfeat.shape
# Out:
# (80000, 51)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

param_grid = [{'min_child_weight': np.arange(0.1, 10.1, 0.1)}]
#set of trial values for min_child_weight
i=1
kf = StratifiedKFold(n_splits=10,random_state=1,shuffle=True)
for train_index,test_index in kf.split(X,y):
     print('\n{} of kfold {}'.format(i,kf.n_splits))
     xtr,xvl = X.loc[train_index],X.loc[test_index]
     ytr,yvl = y[train_index],y[test_index]
     model = GridSearchCV(XGBClassifier(), param_grid, cv=5, scoring= 'roc_auc',iid=True)
     model.fit(xtr, ytr)
     print (model.best_params_)
     pred=model.predict(xvl)
     print('r_a_score',roc_auc_score(yvl,pred))
     i+=1
# Out:
# 1 of kfold 10
